# %%
import numpy as np
import pandas as pd
from clusterlogs import pipeline
import nltk

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv('error1109.txt')

# %%
df.head(10)
# Out:
#               src_site   dst_site  \
# 0  BelGrid-UCL          NaN
# 1  UKI-SOUTHGRID-RALPP  NaN
# 2  DESY-HH              UCSDT2
# 3  DESY-HH              UCSDT2
# 4  UCSDT2               KR-KNU-T3
# 5  KR-KNU-T3            NaN
# 6  CIT_CMS_T2           KR-KNU-T3
# 7  BEIJING-LCG2         NaN
# 8  NaN                  INFN-T1
# 9  DESY-HH              UCSDT2
#
#                                                                                                                                                                                                                                                                                                                     error  \
# 0  TRANSFER  Transfer canceled because the gsiftp performance marker timeout of 360 seconds has been exceeded, or all performance markers during that period indicated zero bytes transferred
# 1  TRANSFER  Transfer canceled because the gsiftp performance marker timeout of 360 seconds has been exceeded, or all performance markers during that period indicated zero bytes transferred
# 2  srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on cmsftssrv1.fnal.gov reports could not open connection to dcache-se-cms.desy.de:8443
# 3  srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on cmsftssrv1.fnal.gov reports could not open connection to dcache-se-cms.desy.de:8443
# 4  TRANSFER  globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3021] Unable to get quota space - quota not defined or exhausted /eos/cms/store/user/chench/JetHT/C/191107_211030/0000/log/cmsRun_394.log.tar.gz; Disk quota exceeded
# 5  TRANSFER  globus_xio: Unable to connect to dpms29.indiacms.res.in:2811 globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out
# 6  TRANSFER  globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3021] Unable to get quota space - quota not defined or exhausted /eos/cms/store/user/chench/JetHT/E/191107_204933/0000/log/cmsRun_679.log.tar.gz; Disk quota exceeded
# 7  TRANSFER  Operation timed out
# 8  TRANSFER  Transfer canceled because the gsiftp performance marker timeout of 360 seconds has been exceeded, or all performance markers during that period indicated zero bytes transferred
# 9  srm-ifce err: Communication error on send, err: [SE][Ls][] httpg://dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on cmsftssrv1.fnal.gov reports could not open connection to dcache-se-cms.desy.de:8443
#
#   type
# 0  cms
# 1  cms
# 2  cms
# 3  cms
# 4  cms
# 5  cms
# 6  cms
# 7  cms
# 8  cms
# 9  cms

# %% [markdown]
# Most failing sites according to the results from Panos algorithm

# %%
from IPython.display import Image
Image(filename='tot_fail1109.png')

# %% [markdown]
# Chose a few with the biggest fail rate

# %%
df_krknu = df[(df['src_site']=='KR-KNU-T3') | (df['dst_site']=='KR-KNU-T3')]
df_ucl = df[(df['src_site']=='BelGrid-UCL') | (df['dst_site']=='BelGrid-UCL')]
df_desy = df[(df['src_site']=='DESY-HH') | (df['dst_site']=='DESY-HH')]
print(df_krknu.shape, df_ucl.shape, df_desy.shape)
# Out:
# (117345, 4) (23590, 4) (23938, 4)

# %%
cluster_krknu = pipeline.Chain(df_krknu, target='error', model_name='word2vec_krknu.model', mode='create')
cluster_ucl = pipeline.Chain(df_ucl, target='error', model_name='word2vec_ucl.model', mode='create')
cluster_desy = pipeline.Chain(df_desy, target='error', model_name='word2vec_desy.model', mode='create')

# %%
cluster_krknu.process()
cluster_ucl.process()
cluster_desy.process()
# Out:
# /home/ntuckus/test/error-log-clustering/jupyter/clusterlogs/pipeline.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['sequence'] = self.tokens.tokenized_cluster
# /home/ntuckus/test/error-log-clustering/jupyter/clusterlogs/pipeline.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['tokenized_pattern'] = self.tokens.tokenized_pattern
# Initial size of vocabulary: 10385
# Size of vocabulary after removing tokens that appears only once: 7786
# Size of vocabulary after removing rare tokens: 564
# Tokenization finished
# /home/ntuckus/test/error-log-clustering/jupyter/clusterlogs/pipeline.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['cleaned'] = self.tokens.detokenize(cleaned_tokens)
# Found 397 equal groups
# Vectorization of tokens finished
# Vectorization of sentences is finished
# Vocabulary size = 10385
# Number of dimensions is 102
# DBSCAN finished with 220 clusters
# Matching Clusterization...
# division by zero
# /home/ntuckus/test/error-log-clustering/jupyter/clusterlogs/pipeline.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['sequence'] = self.tokens.tokenized_cluster
# /home/ntuckus/test/error-log-clustering/jupyter/clusterlogs/pipeline.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['tokenized_pattern'] = self.tokens.tokenized_pattern
# Initial size of vocabulary: 698
# Size of vocabulary after removing tokens that appears only once: 331
# Size of vocabulary after removing rare tokens: 218
# Tokenization finished
# /home/ntuckus/test/error-log-clustering/jupyter/clusterlogs/pipeline.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['cleaned'] = self.tokens.detokenize(cleaned_tokens)
# Found 76 equal groups
# Matching Clusterization...
# Finished with 50 clusters
# /home/ntuckus/test/error-log-clustering/jupyter/clusterlogs/pipeline.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['sequence'] = self.tokens.tokenized_cluster
# /home/ntuckus/test/error-log-clustering/jupyter/clusterlogs/pipeline.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['tokenized_pattern'] = self.tokens.tokenized_pattern
# Initial size of vocabulary: 2639
# Size of vocabulary after removing tokens that appears only once: 1134
# Size of vocabulary after removing rare tokens: 279
# Tokenization finished
# /home/ntuckus/test/error-log-clustering/jupyter/clusterlogs/pipeline.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['cleaned'] = self.tokens.detokenize(cleaned_tokens)
# Found 172 equal groups
# Matching Clusterization...
# Finished with 76 clusters

# %% [markdown]
# Separating clusters containing fewer than 3 messages

# %%
clusters_krknu, outliers_krknu = cluster_krknu.split_clusters(cluster_krknu.result, 'cluster_size', threshold=3)
clusters_ucl, outliers_ucl = cluster_ucl.split_clusters(cluster_ucl.result, 'cluster_size', threshold=3)
clusters_desy, outliers_desy = cluster_desy.split_clusters(cluster_desy.result, 'cluster_size', threshold=3)

# %% [markdown]
# Top 10 clusters by the size of cluster in each group

# %%
#KR-KNU-T3
top_numb = 10
top_clusters_krknu = cluster_krknu.validation(clusters_krknu)[['cluster_size','pattern','mean_similarity']].sort_values(by=["cluster_size"], ascending=False) #clusters sorted by similarity inside the cluster
top_clusters_krknu.head(top_numb)
# Out:
#    cluster_size  \
# 0  39692
# 1  15064
# 2  10153
# 3  6192
# 4  6166
# 5  5112
# 6  5108
# 7  4713
# 8  3680
# 9  3306
#
#                                                                                                                                                                                                                                                                                                                                                                                                       pattern  \
# 0  TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3021] Unable to get quota space - quota not defined or exhausted /eos/store/user/｟*｠; Disk quota exceeded
# 1  TRANSFER globus_ftp_client: the server responded with an error 421 Service busy: Connection limit exceeded. Please try again later. Closing control connection.
# 2  TRANSFER Transfer canceled because the gsiftp performance marker timeout of 360 seconds has been exceeded, or all performance markers during that period indicated zero bytes transferred
# 3  TRANSFER globus_xio: Unable to connect to :2811 globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out
# 4  globus_ftp_client: the server responded with an error 530 530-globus_xio: Authentication Error 530-OpenSSL Error: s3_srvr.c: in library: SSL routines, function : certificate 530-globus_gsi_callback_module: Could not verify credential 530-globus_gsi_callback_module: The certificate has expired: Credential with subject: /DC=ch/DC=cern/OU=Organic Units/OU=Users/CN=/CN=/CN= /CN=/CN= has expired.
# 5  the :
# 6  DESTINATION CHECKSUM globus_ftp_client: the server responded with an error 421 Service busy: Connection limit exceeded. Please try again later. Closing control connection.
# 7  TRANSFER Operation timed out
# 8  srm-ifce err: Communication error on send, err: [SE][Ls][] httpg:/dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on reports could not open connection to dcache-se-cms.desy.de:8443
# 9  TRANSFER an end-of-file was reached globus_xio: An end of file occurred
#
#    mean_similarity
# 0  0.68
# 1  1.00
# 2  1.00
# 3  0.98
# 4  0.77
# 5  0.15
# 6  1.00
# 7  1.00
# 8  0.91
# 9  1.00

# %%
#BelGrid-UCL
top_clusters_ucl = cluster_ucl.validation(clusters_ucl)[['cluster_size','pattern','mean_similarity']].sort_values(by=["cluster_size"], ascending=False) #clusters sorted by similarity inside the cluster
top_clusters_ucl.head(top_numb)
# Out:
#    cluster_size  \
# 0  11336
# 1  6478
# 2  2518
# 3  1062
# 4  643
# 5  556
# 6  307
# 7  178
# 8  124
# 9  54
#
#                                                                                                                                                                                                                                                                                                       pattern  \
# 0  TRANSFER Transfer canceled because the gsiftp performance marker timeout of 360 seconds has been exceeded, or all performance markers during that period indicated zero bytes transferred
# 1  TRANSFER an end-of-file was reached globus_xio: An end of file occurred
# 2  ｟*｠ CHECKSUM an end-of-file was reached globus_xio: An end of file occurred
# 3  Destination file exists and overwrite is not enabled
# 4  TRANSFER Operation timed out
# 5  TRANSFER globus_xio: System error in recv: Connection timed out globus_xio: A system call failed: Connection timed out
# 6  ｟*｠ globus_xio: System error in recv: Connection reset by peer globus_xio: A system call failed: Connection reset by peer
# 7  TRANSFER globus_ftp_client: the server responded with an error 451 451-GlobusError: v=1 c=INTERNAL_ERROR 451-GridFTP-Errno: 255 451-GridFTP-Reason: System error in write into HDFS (host=｟*｠, user=｟*｠, path=/｟*｠/store/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠) 451-GridFTP-Error-String: Unknown error 255 451 End.
# 8  ｟*｠ srm-ifce err: Communication error on send, err: [SE][｟*｠][] httpg:/dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on｟*｠ reports could not open connection to dcache-se-cms.desy.de:8443
# 9  TRANSFER globus_ftp_client: the server responded with an error 451 General problem: Problem while connected to [2001:6a8:3081:1201:1:｟*｠]:｟*｠:｟*｠
#
#    mean_similarity
# 0  1.00
# 1  1.00
# 2  0.94
# 3  1.00
# 4  1.00
# 5  1.00
# 6  0.90
# 7  0.69
# 8  0.92
# 9  0.89

# %%
#DESY-HH
top_clusters_desy = cluster_desy.validation(clusters_desy)[['cluster_size','pattern','mean_similarity']].sort_values(by=["cluster_size"], ascending=False) #clusters sorted by similarity inside the cluster
top_clusters_desy.head(top_numb)
# Out:
#    cluster_size  \
# 0  8072
# 1  6369
# 2  2168
# 3  1343
# 4  1155
# 5  1031
# 6  799
# 7  535
# 8  483
# 9  309
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                pattern  \
# 0  ｟*｠ srm-ifce err: Communication error on send, err: [SE][｟*｠][] httpg:/dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on｟*｠ reports could not open connection to dcache-se-cms.desy.de:8443
# 1  srm-ifce err: Communication error on send, err: [SE][Ls][] httpg:/｟*｠:｟*｠/srm/managerv2: CGSI-gSOAP running on t3serv019.mit.edu reports Could NOT load client credentials GSS Major Status: General failure GSS Minor Status Error Chain: globus_gsi_gssapi: Error with GSI credential globus_gsi_gssapi: Error with gss credential handle globus_credential: Valid credentials could not be found in any of the possible locations specified by the credential search order. Valid credentials｟*｠
# 2  Destination file exists and overwrite is not enabled
# 3  TRANSFER globus_ftp_client: the server responded with an error 451 451-GlobusError: v=1 c=INTERNAL_ERROR 451-GridFTP-Errno: 255 451-GridFTP-Reason: System error in write into HDFS (host=｟*｠, user=cms, path=/cms/store/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠) 451-GridFTP-Error-String: Unknown error 255 451 End.
# 4  TRANSFER Transfer canceled because the gsiftp performance marker timeout of 360 seconds has been exceeded, or all performance markers during that period indicated zero bytes transferred
# 5  ｟*｠ globus_xio: Unable to connect to｟*｠:2811 globus_xio: System error in connect: Connection timed out globus_xio: A system call failed: Connection timed out
# 6  TRANSFER globus_ftp_client: the server responded with an error 451 451-GlobusError: v=1 c=INTERNAL_ERROR 451-GridFTP-Errno: 255 451-GridFTP-Reason: System error in write into HDFS (host=｟*｠, user=cms, path=/cms/store/data/｟*｠/｟*｠/｟*｠/｟*｠/000/｟*｠/｟*｠/00000/｟*｠) 451-GridFTP-Error-String: Unknown error 255 451 End.
# 7  DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg:/dcache-se-cms.desy.de:8443/srm/managerv2: CGSI-gSOAP running on t3serv019.mit.edu reports could not open connection to dcache-se-cms.desy.de:8443
# 8  ｟*｠ globus_ftp_client: the server responded with an error 421 Service busy: Connection limit exceeded. Please try again later. Closing control connection.
# 9  ｟*｠ globus_xio: System error in recv: Connection reset by peer globus_xio: A system call failed: Connection reset by peer
#
#    mean_similarity
# 0  0.88
# 1  0.95
# 2  1.00
# 3  0.70
# 4  1.00
# 5  0.89
# 6  0.89
# 7  1.00
# 8  0.94
# 9  0.90

# %% [markdown]
# Most inaccurate clusters

# %%
#KR-KNU-T3
top_clusters_krknu[['cluster_size','pattern','mean_similarity']].sort_values(by=["mean_similarity"]).head(5)
# Out:
#      cluster_size  \
# 5    5112
# 51   40
# 0    39692
# 53   37
# 142  3
#
#                                                                                                                                                                                                                                                    pattern  \
# 5    the :
# 51   globus_ftp_client: the server responded with an error 500 error
# 0    TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : open/create : [ERROR] Server responded with an error: [3021] Unable to get quota space - quota not defined or exhausted /eos/store/user/｟*｠; Disk quota exceeded
# 53   Error reported from srm_ifce : 2 [SE][Ls][SRM_INVALID_PATH] No such file or directory /pnfs/data/cms/store/
# 142  TRANSFER globus_ftp_client: the server responded with an error 500 500-Command failed. : System error in : system call failed: 500 End.
#
#      mean_similarity
# 5    0.15
# 51   0.62
# 0    0.68
# 53   0.68
# 142  0.69

# %%
#BelGrid-UCL
top_clusters_ucl[['cluster_size','pattern','mean_similarity']].sort_values(by=["mean_similarity"]).head(5)
# Out:
#     cluster_size  \
# 7   178
# 19  11
# 15  17
# 16  14
# 9   54
#
#                                                                                                                                                                                                                                                                                                        pattern  \
# 7   TRANSFER globus_ftp_client: the server responded with an error 451 451-GlobusError: v=1 c=INTERNAL_ERROR 451-GridFTP-Errno: 255 451-GridFTP-Reason: System error in write into HDFS (host=｟*｠, user=｟*｠, path=/｟*｠/store/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠) 451-GridFTP-Error-String: Unknown error 255 451 End.
# 19  DESTINATION SRM_PUT_TURL error on the turl request : [SE][StatusOfPutRequest][SRM_INVALID_PATH] Failed to put /storage/data/cms/store/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠
# 15  ｟*｠ CHECKSUM Operation timed out
# 16  DESTINATION EXISTS Destination already exist gsiftp:/eoscmsftp.cern.ch/eos/cms/store/mc/RunIISummer19UL18wmLHEGEN/｟*｠/｟*｠/106X_upgrade2018_realistic_v4-v1/｟*｠/｟*｠, Cancel
# 9   TRANSFER globus_ftp_client: the server responded with an error 451 General problem: Problem while connected to [2001:6a8:3081:1201:1:｟*｠]:｟*｠:｟*｠
#
#     mean_similarity
# 7   0.69
# 19  0.70
# 15  0.84
# 16  0.89
# 9   0.89

# %%
#DESY-HH
top_clusters_desy[['cluster_size','pattern','mean_similarity']].sort_values(by=["mean_similarity"]).head(5)
# Out:
#     cluster_size  \
# 3   1343
# 22  37
# 10  274
# 18  49
# 17  53
#
#                                                                                                                                                                                                                                                                                                        pattern  \
# 3   TRANSFER globus_ftp_client: the server responded with an error 451 451-GlobusError: v=1 c=INTERNAL_ERROR 451-GridFTP-Errno: 255 451-GridFTP-Reason: System error in write into HDFS (host=｟*｠, user=cms, path=/cms/store/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠/｟*｠) 451-GridFTP-Error-String: Unknown error 255 451 End.
# 22  TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : Failed to close file in HDFS. (host=｟*｠, user=cms, path=/cms/store/data/｟*｠/｟*｠/｟*｠/｟*｠/000/｟*｠/｟*｠/00000/｟*｠)
# 10  DESTINATION SRM_PUTDONE call to srm_ifce error: [SE][PutDone][] httpg:/｟*｠:8443/srm/managerv2: CGSI-gSOAP running on｟*｠ reports Error reading token data header: Connection｟*｠
# 18  ｟*｠ srm-ifce err: Communication error on send, err: [SE][｟*｠][] httpg:/｟*｠:｟*｠/srm/managerv2: CGSI-gSOAP running on t3serv019.mit.edu reports Error reading token data header: Connection｟*｠
# 17  TRANSFER CHECKSUM MISMATCH Source and destination checksums do not match｟*｠ !=｟*｠
#
#     mean_similarity
# 3   0.70
# 22  0.77
# 10  0.81
# 18  0.84
# 17  0.85
