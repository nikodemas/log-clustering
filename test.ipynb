# %%
import numpy as np
import pandas as pd
from clusterlogs import pipeline

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv('data/error0101.txt')
#df = pd.read_csv('data/error0102.txt')
#df = pd.read_csv('data/error0115.txt')
#df = pd.read_csv('data/error0201.txt')
#df = pd.read_csv('data/error0225.txt')

# %%
df.head()
# Out:
#                                                                                                                                                                                       error_message
# 0  globus_ftp_client: the server responded with an error 500 500-Command failed : System error in stat: No such file or directory  500-A system call failed: No such file or directory  500 End.
# 1  Error on XrdCl::CopyProcess::Run(): [ERROR] Server responded with an error: [3010] Write permission denied
# 2  globus_ftp_client: the server responded with an error 500 500-Command failed : System error in stat: No such file or directory  500-A system call failed: No such file or directory  500 End.
# 3  globus_ftp_client: the server responded with an error 500 Command failed : stat64 error: No such file or directory
# 4  globus_ftp_client: the server responded with an error 500 500-Command failed : System error in stat: No such file or directory  500-A system call failed: No such file or directory  500 End.

# %%
df.shape
# Out:
# (703546, 1)

# %%
cluster = pipeline.Chain(df, target='error_message', mode='create')

# %%
cluster.process()
# Out:
# Tokenization finished
# Found 21755 equal groups
# Vectorization of tokens finished
# Vectorization of sentences is finished
# Vocabulary size = 18847
# Number of dimensions is 137
# DBSCAN finished with 10045 clusters
# Matching Clusterization!
# Postprocessed with 371 clusters

# %%
#some of the clusters
cluster.result.head(5)
# Out:
#                                                                                                                                            pattern  \
# 1   err: Communication error on send, err: [SE][][] httpg:/:/srm/: CGSI-gSOAP running on reports Error reading token data header: Connection
# 0   Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: []
# 42  Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: [4003] Authentication to:1094 failed; all protocols have been tried.
# 4   : the server responded with an error 500 error in: No such file or directory 500-A system call failed: No such file or directory 500 End.
# 2   Destination file exists and overwrite is not enabled
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              indices  \
# 1   [5317, 5375, 5449, 5515, 5569, 5623, 5654, 5678, 5705, 5722, 5738, 5794, 5819, 5910, 5917, 5930, 5942, 5951, 5968, 5992, 6007, 6056, 6073, 6192, 6235, 6281, 6286, 6325, 6354, 6363, 6403, 6409, 6422, 6484, 6514, 6525, 6555, 6599, 6626, 6639, 6728, 6746, 6759, 6779, 6800, 6811, 6896, 6906, 6910, 6925, 6944, 6953, 7012, 7042, 7101, 7102, 7110, 7118, 7131, 7237, 7300, 7324, 7397, 7446, 7620, 8012, 8614, 8694, 8997, 9008, 9627, 9633, 10031, 10208, 10703, 10713, 11007, 11042, 11088, 11181, 11219, 11249, 11423, 11563, 11575, 11613, 11700, 11749, 11844, 11848, 12320, 12607, 12615, 12629, 12638, 12875, 13080, 13099, 13106, 13208, ...]
# 0   [1, 18, 83, 93, 110, 133, 184, 274, 287, 289, 297, 304, 359, 360, 394, 397, 400, 406, 429, 434, 439, 442, 450, 457, 461, 463, 465, 466, 481, 490, 495, 511, 525, 527, 533, 535, 549, 573, 577, 579, 591, 592, 622, 641, 670, 674, 694, 715, 722, 726, 763, 770, 809, 841, 844, 875, 879, 887, 888, 901, 909, 911, 937, 939, 960, 965, 970, 980, 1004, 1010, 1020, 1048, 1054, 1095, 1098, 1122, 1138, 1144, 1145, 1167, 1170, 1175, 1185, 1217, 1240, 1257, 1272, 1273, 1297, 1300, 1316, 1331, 1337, 1346, 1351, 1355, 1361, 1373, 1380, 1411, ...]
# 42  [530, 633, 738, 1299, 1531, 1940, 2274, 2765, 3242, 3432, 4308, 4448, 4509, 4830, 4923, 5002, 5030, 5075, 5264, 5380, 5704, 5762, 5767, 6096, 6462, 6773, 8007, 9035, 9232, 9554, 12535, 12551, 12640, 13004, 13352, 13552, 13597, 14139, 14801, 14845, 14910, 14932, 15146, 16677, 16810, 16845, 18054, 19013, 19029, 20185, 20238, 21101, 21157, 21197, 21275, 21348, 21577, 22144, 22213, 22340, 22698, 23469, 23537, 23961, 24895, 25801, 28081, 28189, 28315, 28898, 29193, 29510, 32132, 32724, 32819, 33649, 33861, 34364, 35369, 38373, 39439, 39476, 40175, 40281, 40660, 42306, 42506, 44848, 46223, 46356, 46976, 47210, 47397, 47793, 49352, 50647, 50872, 50994, 51191, 51218, ...]
# 4   [0, 2, 4, 5, 8, 10, 16, 17, 28, 46, 47, 54, 62, 63, 64, 66, 69, 71, 90, 104, 105, 138, 144, 159, 167, 170, 171, 172, 187, 192, 195, 196, 198, 200, 205, 206, 212, 221, 222, 223, 231, 232, 235, 237, 238, 251, 254, 257, 285, 312, 313, 335, 336, 349, 354, 361, 362, 384, 387, 388, 389, 390, 396, 398, 399, 410, 411, 413, 414, 416, 419, 426, 435, 451, 480, 493, 512, 518, 519, 588, 597, 598, 660, 662, 666, 672, 681, 687, 688, 695, 699, 702, 703, 705, 706, 713, 716, 717, 719, 730, ...]
# 2   [43, 81, 129, 255, 293, 295, 296, 498, 510, 517, 522, 712, 890, 967, 1032, 1068, 1121, 1259, 1323, 1347, 1396, 1431, 1580, 1589, 1614, 1636, 1676, 1746, 1789, 2084, 2088, 2091, 2094, 2098, 2177, 2197, 2248, 2254, 2282, 2295, 2410, 2412, 2449, 2506, 2517, 2545, 2588, 2646, 2749, 2753, 2756, 2776, 2787, 2804, 2828, 2915, 2932, 2965, 3039, 3106, 3217, 3557, 3567, 3648, 3662, 3683, 3696, 3754, 3765, 3828, 3926, 3970, 4174, 4258, 4270, 4273, 4354, 4358, 4376, 4492, 4555, 4600, 4672, 4701, 4710, 4714, 4754, 4770, 4852, 4872, 4876, 4897, 4917, 4918, 5015, 5072, 5093, 5094, 5105, 5124, ...]
#
#     cluster_size
# 1   79615
# 0   60088
# 42  29732
# 4   29279
# 2   26537

# %%
#some messages from the cluster 2
print(cluster.in_cluster(cluster.result, 2),"\n")
# Out:
# ['Destination file exists and overwrite is not enabled'
#  'Destination file exists and overwrite is not enabled'
#  'Destination file exists and overwrite is not enabled' ...
#  'Destination file exists and overwrite is not enabled'
#  'Destination file exists and overwrite is not enabled'
#  'Destination file exists and overwrite is not enabled']

# %%
#cluster.result['pattern'].values

# %%
clusters, outliers = cluster.split_clusters(cluster.result, 'cluster_size', threshold=3)
outliers.head(10) #clusters containing fewer than 3 messages
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                pattern  \
# 340  DESTINATION SRM_PUT_TURL error on the turl request : [SE][StatusOfPutRequest][SRM_INVALID_PATH] Parent /gpfs/ddn/srm/cms/store/data/////000/ doesnt｟*｠!
# 329  TRANSFER ERROR: Copy failed with mode 3rd push, with error: Transfer failed: failure: Remote copy failed with status code 0: Failed to connect to｟*｠ 443:
# 364  TRANSFER globus_ftp_client: the server responded with an error｟*｠ General problem: Failed to connect [2406:f00:9:]::
# 318  DESTINATION EXISTS Destination already｟*｠ gsiftp:/eoscmsftp.cern.ch/eos/cms/store/mc///GEN/106X_upgrade2018_realistic_v4-v1//, Cancel
# 315  DESTINATION SRM_PUTDONE Error on the surl srm:/se.cis.gov.pl/dpm/cis.gov.pl/home/cms/store/data/Run2017D/JetHT/AOD/09Aug2019_UL2017-v1// while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status
# 311  DESTINATION SRM_PUTDONE Error on the surl srm:////rucio/mc16_13TeV///. while putdone : [SE][PutDone][SRM_INTERNAL_ERROR] Request to [>PnfsManager@local] timed out.
# 362  TRANSFER globus_ftp_client: the server responded with an error｟*｠ General problem: Failed to connect [2001:660:5009:9:193:48:99:]:: Connection timed out
# 343  DESTINATION SRM_PUT_TURL error on the turl request : [SE][StatusOfPutRequest][] error accessing belle2grid4.cc.ntu.edu.tw://belle/2020-01-02: out
# 366  TRANSFER globus_ftp_client: the server responded with an error｟*｠ 550-GlobusError: v=1 c=PERMISSION_DENIED 550-GridFTP-Errno: 13 550-GridFTP-Reason: System error in mkdir (host=, user=cmsphedx, path=/store/generator/Summer13/GluGluToHHToTauTauBB_M-125_14TeV-powheg-pythia6/GEN/UpgrdPhase1Age5H_STAR17_61_V5A-v1/00000) 550-GridFTP-Error-String: Permission denied｟*｠ End.
# 307  Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: [｟*｠] [ERROR] Server responded with an error: [｟*｠] Unable to read /pnfs/usatlas.bnl.gov/atlasscratchdisk/rucio/tests///; function not｟*｠
#
#               indices  cluster_size
# 340  [225297, 180602]  2
# 329  [539911, 440066]  2
# 364  [142888, 275693]  2
# 318  [424553, 316501]  2
# 315  [120527, 218340]  2
# 311  [298977, 93086]   2
# 362  [687322, 243397]  2
# 343  [372460, 112982]  2
# 366  [256947, 501180]  2
# 307  [292245, 251640]  2

# %%
#top 20 clusters by the size of cluster
top_numb = 20
top_clusters = cluster.validation(clusters)[['cluster_size','pattern','mean_similarity']].sort_values(by=["cluster_size"], ascending=False) #clusters sorted by similarity inside the cluster
top_clusters.head(top_numb)
# Out:
#     cluster_size  \
# 0   79615
# 1   60088
# 2   29732
# 3   29279
# 4   26537
# 5   24407
# 6   19802
# 7   18333
# 8   18207
# 9   17760
# 10  16797
# 11  15907
# 12  15783
# 13  14821
# 14  14629
# 15  14581
# 16  13091
# 17  12665
# 18  12409
# 19  11878
#
#                                                                                                                                                                                                                                                                                                                                                  pattern  \
# 0   err: Communication error on send, err: [SE][][] httpg:/:/srm/: CGSI-gSOAP running on reports Error reading token data header: Connection
# 1   Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: []
# 2   Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: [4003] Authentication to:1094 failed; all protocols have been tried.
# 3   : the server responded with an error 500 error in: No such file or directory 500-A system call failed: No such file or directory 500 End.
# 4   Destination file exists and overwrite is not enabled
# 5   ｟*｠: Unable to connect to:2811｟*｠: System error in connect: Connection｟*｠: A system call failed: Connection
# 6   Error reported from srm_ifce : 2 [SE][Ls][SRM_INVALID_PATH] No such file or directory
# 7   end-of-file was reached｟*｠: An end of file occurred
# 8   [gfalt_copy_file][perform_copy][gfal_xrootd_3rd_copy][gfal_xrootd_3rd_copy_bulk] Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: []
# 9   SOURCE SRM_GET_TURL error on the turl request : [SE][][SRM_FILE_UNAVAILABLE] File is.
# 10  TRANSFER Transfer canceled because the gsiftp performance marker timeout of 360 seconds has been exceeded, or all performance markers during that period indicated zero bytes transferred
# 11  Protocol not supported or path/url invalid: root:/:1094/dpm//home/atlas/atlasscratchdisk/rucio/tests///
# 12  err: Communication error on send, err: [SE][][] httpg:/:/srm/managerv2: CGSI-gSOAP running on reports could not open connection to:
# 13  Protocol not supported or path/url invalid: root:/:1094//atlas/atlasscratchdisk/rucio/tests///
# 14  Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: [] Unable to //////;
# 15  Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: [3010] Unable to open /dpm/nipne.ro/home/atlas/atlasscratchdisk/rucio/tests//; no delegated credentials for tpc
# 16  : the server responded with an error 421 Service busy: Connection limit exceeded. Please try again later. Closing control connection.
# 17  : the server responded with an error 530 530-globus_xio: Authentication Error 530-OpenSSL Error: s3_srvr.c:: in library: SSL routines, function: certificate 530-globus_gsi_callback_module: Could not verify credential 530-globus_gsi_callback_module: The certificate: with subject: /DC=ch/DC=cern/OU=Organic Units/OU=Users/CN=/CN=/CN=/CN=/CN=
# 18  Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: [3010] Unable to create /pnfs/usatlas.bnl.gov/atlasscratchdisk/rucio/tests///; permission denied
# 19  Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: [3010] Access denied: /pnfs/triumf.ca/data/atlas/atlasscratchdisk/rucio/tests//
#
#     mean_similarity
# 0   0.94
# 1   0.99
# 2   0.90
# 3   0.98
# 4   1.00
# 5   0.89
# 6   0.99
# 7   1.00
# 8   0.99
# 9   1.00
# 10  1.00
# 11  0.68
# 12  0.84
# 13  0.66
# 14  0.61
# 15  0.86
# 16  0.98
# 17  0.96
# 18  0.85
# 19  0.84

# %%
#most inaccurate clusters
top_clusters[['cluster_size','pattern','mean_similarity']].sort_values(by=["mean_similarity"]).head(10)
# Out:
#      cluster_size  \
# 14   14629
# 13   14821
# 11   15907
# 26   8445
# 170  39
# 289  3
# 21   11260
# 42   3484
# 292  3
# 199  16
#
#                                                                                                                                                                                                                    pattern  \
# 14   Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: [] Unable to //////;
# 13   Protocol not supported or path/url invalid: root:/:1094//atlas/atlasscratchdisk/rucio/tests///
# 11   Protocol not supported or path/url invalid: root:/:1094/dpm//home/atlas/atlasscratchdisk/rucio/tests///
# 26   Protocol not supported or path/url invalid: root:/:1094//atlasscratchdisk/rucio/tests///
# 170  DESTINATION SRM_PUTDONE Error on the surl srm://dpm//home/cms/store/////// while putdone : [SE][PutDone][SRM_FAILURE] Incompatible with current file status
# 289  DESTINATION SRM_PUTDONE Error on the surl srm:/se01.indiacms.res.in/dpm/indiacms.res.in/home/cms/store/user/////// while putdone : [SE][PutDone][SRM_INTERNAL_ERROR]｟*｠ out
# 21   Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: [3012] sync - TPC open failed for src_url=root:/://atlasscratchdisk/rucio/tests///?fst.readahead=true
# 42   Protocol not supported or path/url invalid: root:/:1094/pnfs//atlasscratchdisk/rucio/tests///
# 292  TRANSFER globus_ftp_client: the server responded with an error 500 Command failed. : Failed to close file in HDFS. (host=, user=, path=/store///////)
# 199  DESTINATION MAKE_PARENT srm-ifce err: Permission denied, err: [SE][Mkdir][SRM_AUTHORIZATION_FAILURE] httpg:/:8443/srm/managerv2: srm://castor/ads.rl.ac.uk/prod///////: User can not create a directory at this level
#
#      mean_similarity
# 14   0.61
# 13   0.66
# 11   0.68
# 26   0.70
# 170  0.70
# 289  0.70
# 21   0.74
# 42   0.74
# 292  0.74
# 199  0.74

# %%
perc = round(top_clusters['cluster_size'].head(20).sum()/(df.shape[0]-1)*100,2)
f"{perc}% of all logs are in the top {top_numb} of {len(cluster.result)} clusters"
# Out:
# '66.28% of all logs are in the top 20 of 371 clusters'

# %%
cluster.timings
# Out:
# {'tokenization': 314.0405,
#  'group_equals': 30.2672,
#  'tokens_vectorization': 2.7288,
#  'sentence_vectorization': 4.0955,
#  'ml_clusterization': 5.7293,
#  'matching_clusterization': 10.5776,
#  'process': 367.4536,
#  'validation': 8.3687}

# %%
top_clusters.head(top_numb).to_csv("topclusters0101.txt")
