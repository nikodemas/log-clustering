# %%
import numpy as np
import pandas as pd
import random as rd

# %%
pd.set_option('display.max_colwidth', 150)

# %%
df_err = pd.read_csv('ascii_errors.txt')
df_pat = pd.read_csv('ascii_patterns.txt')

# %%
df_err.head()
# Out:
#                   time  \
# 0  2020-01-05 03:00:00
# 1  2020-01-05 03:00:00
# 2  2020-01-05 03:00:00
# 3  2020-01-05 03:00:00
# 4  2020-01-05 03:00:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            error_message  \
# ...

# %%
df_pat.head(60)
# Out:
#                                                                                                                                                   pattern  \
# 0                                                   Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: [3010]｟*｠ permission denied
# 1   srm-ifce err: Communication error on send, err: [SE][｟*｠][] httpg:/｟*｠:｟*｠/srm/｟*｠: CGSI-gSOAP running on｟*｠ reports Error reading token data head...
# 2                                                             SOURCE SRM_GET_TURL error on the turl request : [SE][｟*｠][SRM_FILE_UNAVAILABLE] File is｟*｠.
# 3   ｟*｠ globus_ftp_client: the server responded with an error 421 Service busy: Connection limit exceeded. Please try again later. Closing control con...
# 4       Error on XrdCl:CopyProcess:Run(): [ERROR] Server responded with an error: [4003] Authentication to｟*｠:1094 failed; all protocols have been tried.
# ...

# %%
df_pat.loc(0,'pattern')

# %%
df_err['cluster_pattern']='1'

# %%
df_err.loc[22,'cluster_pattern']=df_pat.loc[0,'pattern']#Xrd
df_err.loc[614,'cluster_pattern']=df_pat.loc[1,'pattern']#srm
df_err.loc[81,'cluster_pattern']=df_pat.loc[2,'pattern']#SOURCE PUT TURL
df_err.loc[1343,'cluster_pattern']=df_pat.loc[3,'pattern']#globus
df_err.loc[1406,'cluster_pattern']=df_pat.loc[6,'pattern']#protocol
df_err.loc[157,'cluster_pattern']=df_pat.loc[7,'pattern']#TRANSFER
df_err.loc[166,'cluster_pattern']=df_pat.loc[9,'pattern']#DESTINATION PUT TURL
df_err.loc[355,'cluster_pattern']=df_pat.loc[11,'pattern']#DESTINATION
df_err.loc[141,'cluster_pattern']=df_pat.loc[12,'pattern']#TRANSFER
df_err.loc[523,'cluster_pattern']=df_pat.loc[13,'pattern']#DESTINATION
df_err.loc[1231,'cluster_pattern']=df_pat.loc[15,'pattern']#TRANSFER
df_err.loc[23657,'cluster_pattern']=df_pat.loc[21,'pattern']#globus
df_err.loc[2132,'cluster_pattern']=df_pat.loc[23,'pattern']#CHECKSUM
df_err.loc[34563,'cluster_pattern']=df_pat.loc[28,'pattern']#end of file
df_err.loc[555903,'cluster_pattern']=df_pat.loc[26,'pattern']#DESTINATION
df_err.loc[693,'cluster_pattern']=df_pat.loc[8,'pattern']#srm
df_err.loc[22,'cluster_pattern']=df_pat.loc[0,'pattern']
df_err.loc[22,'cluster_pattern']=df_pat.loc[0,'pattern']
df_err.loc[22,'cluster_pattern']=df_pat.loc[0,'pattern']
df_err.loc[22,'cluster_pattern']=df_pat.loc[0,'pattern']

# %%
df_err.loc[[22],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']].to_csv('ascii_errors/message1.txt',index=False,sep='|')
df_err.loc[[614,693],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']].to_csv('ascii_errors/message2.txt',index=False)
df_err.loc[[81],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']].to_csv('ascii_errors/message3.txt',index=False)
df_err.loc[[1343,23657],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']].to_csv('ascii_errors/message4.txt',index=False)
df_err.loc[[1406],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']].to_csv('ascii_errors/message5.txt',index=False)
df_err.loc[[157,141,1231],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']].to_csv('ascii_errors/message6.txt',index=False)
df_err.loc[[166,355,523,555903],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']].to_csv('ascii_errors/message7.txt',index=False)
df_err.loc[[2132],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']].to_csv('ascii_errors/message8.txt',index=False)
df_err.loc[[34563],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']].to_csv('ascii_errors/message9.txt',index=False)

# %%
df_err.loc[[22,693],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']]
# Out:
#                     time                                      error_message  \
# 22   2020-01-05 03:00:00  Error on XrdCl::CopyProcess::Run(): [ERROR] Se...
# 693  2020-01-05 03:18:00  Error reported from srm_ifce : 2 [SE][Ls][SRM_...
#
#                    src_host                dst_host  \
# 22   xrootd-at1-door.pic.es  basilisk02.westgrid.ca
# 693   srm-eospublic.cern.ch      srm-public.cern.ch
#
#                                                cleaned  \
# 22   Error on XrdCl:CopyProcess:Run(): [ERROR] Serv...
# 693  Error ｟*｠ from srm_ifce : 2 [SE][Ls][SRM_INVAL...
#
#                                        cluster_pattern
# 22   Error on XrdCl:CopyProcess:Run(): [ERROR] Serv...
# 693  Error｟*｠ from srm_ifce : 2 [SE][Ls][SRM_INVALI...

# %%
df_err['cluster_pattern']='1'

# %%
df_err.loc[109275,'cluster_pattern']=df_pat.loc[10,'pattern']
df_err.loc[8606,'cluster_pattern']=df_pat.loc[5,'pattern']

# %%
df_err.loc[[109275,8606,104],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']]
# Out:
#                        time  \
# 109275  2020-01-05 04:32:00
# 8606    2020-01-05 15:21:00
# 104     2020-01-05 03:03:00
#
#                                                                                                                                                 error_message  \
# 109275  Error on XrdCl::CopyProcess::Run(): [ERROR] Server responded with an error: [3010] Unable to open /dpm/nipne.ro/home/atlas/atlasscratchdisk/rucio/...
# 8606    Error on XrdCl::CopyProcess::Run(): [ERROR] Server responded with an error: [3010] Unable to create /atlas/atlasscratchdisk/rucio/tests/15/3c/file...
# 104                                                   Error on XrdCl::CopyProcess::Run(): [ERROR] Server responded with an error: [3005] [FATAL] Auth failed
#
#                            src_host                      dst_host  \
# 109275         t2-dpm-01.na.infn.it               tbit00.nipne.ro
# 8606    lpsc-se-dpm-server.in2p3.fr  xrootd-atlas.cr.cnaf.infn.it
# ...

# %%
df_err.loc[[109275,8606],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']].to_csv('ascii_errors/message_compare1.txt',index=False,sep='|')

# %%
df_err.loc[77,'cluster_pattern']=df_pat.loc[29,'pattern']
df_err.loc[230,'cluster_pattern']=df_pat.loc[32,'pattern']

# %%
df_err.loc[[230,77],['time','error_message','src_host','dst_host','cleaned','cluster_pattern']].to_csv('ascii_errors/message_compare0.txt',index=False,sep='|')
