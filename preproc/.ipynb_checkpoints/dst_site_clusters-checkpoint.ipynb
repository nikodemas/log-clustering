# %%
import numpy as np
import pandas as pd
from clusterlogs import pipeline
import nltk

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# /home/nikodemas/anaconda3/envs/jupyter/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
df = pd.read_csv('error_dst_0105.txt')

# %%
df.head()
# Out:
#             time  \
# 0  1578189601783
# 1  1578189607441
# 2  1578189609698
# 3  1578189611931
# 4  1578189612498
#
#                                                                                                                                                                                                                        error_message
# 0  DESTINATION dcgftp.usatlas.bnl.gov ERROR transfer error copy failed with mode push with error copy could not get the delegation id could not get proxy request error fault soap env server no subcode http not found detail
# 1  DESTINATION gfe02.grid.hep.ph.ic.ac.uk ERROR transfer transfer canceled because the gsiftp performance marker timeout of seconds has been exceeded or all performance markers during that period indicated zero bytes transferred
# 2  DESTINATION ccdavatlas.in2p3.fr ERROR transfer error copy failed with mode push with error copy http conflict file exist
# 3  DESTINATION charon01.westgrid.ca ERROR transfer error copy failed with mode push with error transfer failed failure problem sending data certificate for doesnt match any of the subject alternative names rptaylor@uvic.ca
# 4  DESTINATION fal-pygrid-30.lancs.ac.uk ERROR protocol not supported or path url invalid root pnfs usatlas.bnl.gov atlasscratchdisk rucio tests

# %%
cluster = pipeline.Chain(df, target='error_message', mode='create')

# %%
cluster.process()
# Out:
# Found 4400 equal groups
# ...Matching clusterization
# Finished with 329 clusters

# %%
cluster.result
# Out:
#                                                                                                                                                                                                                                                                                                                             pattern  \
# 11   DESTINATION  ERROR srm ifce err communication error on send err se  httpg srm cgsi gsoap running on reports error reading token data header connection
# 160  DESTINATION  ERROR error on xrdcl copyprocess run error server responded with an error write permission denied
# 6    DESTINATION  ERROR source srm get turl error on the turl request se  srm file unavailable file is .
# 20   DESTINATION  ERROR globus ftp client the server responded with an error service busy connection limit exceeded. please try again later. closing control connection.
# 211  DESTINATION  ERROR error on xrdcl copyprocess run error server responded with an error authentication to failed all protocols have been tried.
# ..                                                                                                                                              ...
# 298  DESTINATION tape-sdrm.t1.grid.kiae.ru ERROR destination srm putdone error on the surl srm data atlas atlasmctape aod while putdone se putdone srm internal error preparedstatementcallback sql update t inodes set inlink inlink + imtime ictime igeneration igeneration+ where inumber error deadlock detected detail process
# 300  DESTINATION grid-srm.physik.rwth-aachen.de ERROR destination srm putdone error on the surl srm grid srm.physik.rwth aachen.de pnfs physik.rwth aachen.de cms store data jetht raw reco while putdone se putdone srm internal error request to >pnfsmanager@local timed out.
# 301  DESTINATION dynafed02.heprc.uvic.ca ERROR destination overwrite result could not connect to server after attempts
# 220  DESTINATION cmsdcatape01.fnal.gov ERROR globus ftp client the server responded with an error login incorrect. mapped user is invalid.
# 201  DESTINATION gfe02.grid.hep.ph.ic.ac.uk ERROR transfer globus ftp client the server responded with an error failed. globus l gfs file open failed. unable to open file system error in open permission denied a system call failed permission denied end.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           tokenized_pattern  \
# 11   [DESTINATION, ▁, ▁, ERROR, ▁, srm, ▁, ifce, ▁, err, ▁, communication, ▁, error, ▁, on, ▁, send, ▁, err, ▁, se, ▁, ▁, httpg, ▁, srm, ▁, cgsi, ▁, gsoap, ▁, running, ▁, on, ▁, reports, ▁, error, ▁, reading, ▁, token, ▁, data, ▁, header, ▁, connection, ▁]
# 160  [DESTINATION, ▁, ▁, ERROR, ▁, error, ▁, on, ▁, xrdcl, ▁, copyprocess, ▁, run, ▁, error, ▁, server, ▁, responded, ▁, with, ▁, an, ▁, error, ▁, write, ▁, permission, ▁, denied]
# 6    [DESTINATION, ▁, ▁, ERROR, ▁, source, ▁, srm, ▁, get, ▁, turl, ▁, error, ▁, on, ▁, the, ▁, turl, ▁, request, ▁, se, ▁, ▁, srm, ▁, file, ▁, unavailable, ▁, file, ▁, is, ▁, .]
# 20   [DESTINATION, ▁, ▁, ERROR, ▁, globus, ▁, ftp, ▁, client, ▁, the, ▁, server, ▁, responded, ▁, with, ▁, an, ▁, error, ▁, service, ▁, busy, ▁, connection, ▁, limit, ▁, exceeded, ., ▁, please, ▁, try, ▁, again, ▁, later, ., ▁, closing, ▁, control, ▁, connection, .]
# 211  [DESTINATION, ▁, ▁, ERROR, ▁, error, ▁, on, ▁, xrdcl, ▁, copyprocess, ▁, run, ▁, error, ▁, server, ▁, responded, ▁, with, ▁, an, ▁, error, ▁, authentication, ▁, to, ▁, failed, ▁, all, ▁, protocols, ▁, have, ▁, been, ▁, tried, .]
# ..                                                                                                                                                                                                                                    ...
# 298  [DESTINATION, ▁, tape-sdrm.t1.grid.kiae.ru, ▁, ERROR, ▁, destination, ▁, srm, ▁, putdone, ▁, error, ▁, on, ▁, the, ▁, surl, ▁, srm, ▁, data, ▁, atlas, ▁, atlasmctape, ▁, aod, ▁, while, ▁, putdone, ▁, se, ▁, putdone, ▁, srm, ▁, internal, ▁, error, ▁, preparedstatementcallback, ▁, sql, ▁, update, ▁, t, ▁, inodes, ▁, set, ▁, inlink, ▁, inlink, ▁, +, ▁, imtime, ▁, ictime, ▁, igeneration, ▁, igeneration, +, ▁, where, ▁, inumber, ▁, error, ▁, deadlock, ▁, detected, ▁, detail, ▁, process]
# 300  [DESTINATION, ▁, grid-srm.physik.rwth-aachen.de, ▁, ERROR, ▁, destination, ▁, srm, ▁, putdone, ▁, error, ▁, on, ▁, the, ▁, surl, ▁, srm, ▁, grid, ▁, srm.physik.rwth, ▁, aachen.de, ▁, pnfs, ▁, physik.rwth, ▁, aachen.de, ▁, cms, ▁, store, ▁, data, ▁, jetht, ▁, raw, ▁, reco, ▁, while, ▁, putdone, ▁, se, ▁, putdone, ▁, srm, ▁, internal, ▁, error, ▁, request, ▁, to, ▁, >, pnfsmanager, @, local, ▁, timed, ▁, out, .]
# 301  [DESTINATION, ▁, dynafed02.heprc.uvic.ca, ▁, ERROR, ▁, destination, ▁, overwrite, ▁, result, ▁, could, ▁, not, ▁, connect, ▁, to, ▁, server, ▁, after, ▁, attempts]
# 220  [DESTINATION, ▁, cmsdcatape01.fnal.gov, ▁, ERROR, ▁, globus, ▁, ftp, ▁, client, ▁, the, ▁, server, ▁, responded, ▁, with, ▁, an, ▁, error, ▁, login, ▁, incorrect, ., ▁, mapped, ▁, user, ▁, is, ▁, invalid, .]
# 201  [DESTINATION, ▁, gfe02.grid.hep.ph.ic.ac.uk, ▁, ERROR, ▁, transfer, ▁, globus, ▁, ftp, ▁, client, ▁, the, ▁, server, ▁, responded, ▁, with, ▁, an, ▁, error, ▁, failed, ., ▁, globus, ▁, l, ▁, gfs, ▁, file, ▁, open, ▁, failed, ., ▁, unable, ▁, to, ▁, open, ▁, file, ▁, system, ▁, error, ▁, in, ▁, open, ▁, permission, ▁, denied, ▁, a, ▁, system, ▁, call, ▁, failed, ▁, permission, ▁, denied, ▁, end, .]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         indices  \
# 11   [530501, 291415, 530338, 5015, 15442, 15740, 40870, 47501, 50061, 73453, 73643, 73687, 73694, 102263, 115060, 115308, 116662, 117199, 165924, 250394, 250550, 267673, 268506, 268622, 295609, 295703, 295814, 295889, 300350, 300399, 312405, 312647, 312833, 323896, 325922, 329679, 393651, 408010, 466809, 467013, 469713, 477548, 488414, 488690, 488818, 496467, 500656, 519273, 519709, 519753, 519755, 519814, 523458, 523640, 523689, 365134, 576355, 576367, 576371, 576382, 576396, 576402, 576419, 576427, 576441, 576445, 576456, 576457, 576470, 576474, 576485, 576496, 576505, 576506, 576519, 576522, 576540, 576541, 576543, 576547, 576554, 576584, 576589, 576591, 576595, 576597, 576598, 576599, 576609, 576611, 576613, 576620, 576621, 576622, 576629, 576634, 576635, 576636, 576637, 576648, ...]
# 160  [10, 22, 57, 86, 88, 113, 345, 422, 543, 620, 731, 749, 910, 981, 1062, 1126, 1138, 1268, 1341, 1479, 1497, 1514, 1518, 1643, 1691, 1765, 1786, 1787, 1793, 1832, 1837, 1947, 1989, 2005, 2010, 2076, 2135, 2563, 2727, 3000, 3022, 3054, 3107, 3144, 3268, 3305, 3318, 3405, 3427, 3499, 3505, 3514, 3560, 3591, 3593, 3619, 3706, 3959, 3988, 4016, 4032, 4077, 4142, 4179, 4189, 4198, 4201, 4202, 4212, 4311, 4317, 4444, 4497, 4546, 4578, 4580, 4583, 4592, 4617, 4618, 4683, 4703, 4756, 4785, 4806, 4816, 4965, 4970, 4972, 5009, 5049, 5051, 5096, 5121, 5184, 5289, 5298, 5539, 5582, 5708, ...]
# 6    [6381, 38856, 234688, 273418, 300126, 365673, 373181, 382142, 412293, 542289, 351988, 408064, 2431, 2637, 2659, 7262, 13146, 14785, 14798, 23403, 23420, 23489, 33451, 33881, 38736, 40089, 46480, 48572, 48625, 50513, 50533, 52496, 57257, 57263, 69818, 69875, 74588, 85449, 85538, 85543, 85679, 88869, 89248, 105621, 106309, 106337, 106472, 112552, 115875, 146436, 150888, 150906, 151047, 158612, 161969, 162330, 162666, 163162, 163167, 180995, 187891, 188050, 188140, 188161, 188277, 191104, 195758, 215482, 235192, 235483, 247498, 251187, 252547, 252636, 252688, 260656, 261107, 277127, 291916, 294883, 305487, 305917, 305994, 313544, 313813, 316646, 326489, 330440, 330453, 330593, 330613, 330714, 331981, 332154, 335097, 336443, 338533, 338661, 343418, 343442, ...]
# 20   [516082, 555867, 2220, 180698, 180700, 294678, 331745, 331773, 516973, 555823, 544858, 2209, 2211, 2243, 23100, 23104, 23107, 23125, 23142, 23147, 23161, 69592, 69602, 69613, 69647, 69654, 69657, 180645, 180657, 180695, 252364, 252381, 252409, 252422, 294679, 294691, 294704, 294707, 294712, 294725, 331741, 331753, 351944, 351984, 516945, 516948, 516951, 516952, 516954, 516960, 516966, 516976, 534360, 534365, 534366, 534369, 534373, 534375, 534376, 534403, 534407, 534408, 534411, 534417, 544823, 544828, 544830, 544835, 544838, 544840, 544857, 544867, 544878, 544880, 544889, 544890, 555800, 555802, 555804, 555808, 555833, 555841, 555858, 294698, 580504, 598810, 610887, 611767, 1984, 1994, 22840, 22864, 22865, 22875, 22876, 22920, 69374, 69383, 180396, 252127, ...]
# 211  [71, 165, 169, 359, 467, 555, 663, 690, 831, 839, 1139, 1207, 1234, 1507, 1611, 1665, 1670, 1672, 1683, 1705, 1713, 1727, 1731, 1805, 1815, 1893, 1919, 1922, 1973, 1978, 2024, 2056, 2060, 2079, 2137, 2480, 2775, 2797, 2837, 2850, 2875, 2903, 2936, 2967, 3048, 3103, 3140, 3159, 3167, 3213, 3263, 3329, 3461, 3507, 3542, 3668, 3688, 3716, 3728, 3741, 3775, 3782, 3815, 3816, 3907, 3940, 3962, 3973, 4075, 4183, 4333, 4334, 4433, 4529, 4567, 4576, 4603, 4607, 4619, 4691, 4698, 4713, 4739, 4749, 4790, 4814, 4874, 4907, 4909, 4929, 4941, 4969, 4981, 5006, 5086, 5109, 5119, 5201, 5270, 5302, ...]
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 298  [465070]
# 300  [494781]
# 301  [143081]
# 220  [584173]
# 201  [522036]
#
#      cluster_size  \
# 11   55424
# 160  52867
# 6    42959
# 20   28596
# 211  27279
# ..     ...
# 298  1
# 300  1
# 301  1
# 220  1
# 201  1
#
#                                                                                                                                                                                                                                                                                                                                                                       sequence  \
# 11   [DESTINATION, ERROR, srm, ifce, err, communication, error, on, send, err, se, httpg, srm, cgsi, gsoap, running, on, reports, error, reading, token, data, header, connection]
# 160  [DESTINATION, ERROR, error, on, xrdcl, copyprocess, run, error, server, responded, with, an, error, write, permission, denied]
# 6    [DESTINATION, ERROR, source, srm, get, turl, error, on, the, turl, request, se, srm, file, unavailable, file, is]
# 20   [DESTINATION, ERROR, globus, ftp, client, the, server, responded, with, an, error, service, busy, connection, limit, exceeded., please, try, again, later., closing, control, connection.]
# 211  [DESTINATION, ERROR, error, on, xrdcl, copyprocess, run, error, server, responded, with, an, error, authentication, to, failed, all, protocols, have, been, tried.]
# ..                                                                                                                                                                   ...
# 298  [DESTINATION, tape-sdrm.t1.grid.kiae.ru, ERROR, destination, srm, putdone, error, on, the, surl, srm, data, atlas, atlasmctape, aod, while, putdone, se, putdone, srm, internal, error, preparedstatementcallback, sql, update, t, inodes, set, inlink, inlink, +, imtime, ictime, igeneration, igeneration+, where, inumber, error, deadlock, detected, detail, process]
# 300  [DESTINATION, grid-srm.physik.rwth-aachen.de, ERROR, destination, srm, putdone, error, on, the, surl, srm, grid, srm.physik.rwth, aachen.de, pnfs, physik.rwth, aachen.de, cms, store, data, jetht, raw, reco, while, putdone, se, putdone, srm, internal, error, request, to, >pnfsmanager@local, timed, out.]
# 301  [DESTINATION, dynafed02.heprc.uvic.ca, ERROR, destination, overwrite, result, could, not, connect, to, server, after, attempts]
# 220  [DESTINATION, cmsdcatape01.fnal.gov, ERROR, globus, ftp, client, the, server, responded, with, an, error, login, incorrect., user, is]
# 201  [DESTINATION, gfe02.grid.hep.ph.ic.ac.uk, ERROR, transfer, globus, ftp, client, the, server, responded, with, an, error, failed., globus, l, file, open, failed., unable, to, open, file, system, error, in, open, permission, denied, a, system, call, failed, permission, denied, end.]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              common_phrases
# 11   [uk error srm ifce err communication error, ch error srm ifce err communication error, ca error srm ifce err communication error, es error srm ifce err communication error, pl error srm ifce err communication error, de error srm ifce err communication error, nl error srm ifce err communication error, kr error srm ifce err communication error, il error srm ifce err communication error, tw error srm ifce err communication error, cz error srm ifce err communication error, fr error srm ifce err communication error, ru error srm ifce err communication error, cn error srm ifce err communication error, org error srm ifce err communication error, su error srm ifce err communication error, ro error srm ifce err communication error, gr error srm ifce err communication error, sk error srm ifce err communication error, br error srm ifce err communication error, edu error srm ifce err communication error, gov error srm ifce err communication error, error srm ifce err communication error, destination lhcbsrm-disk-kit, destination dcache-se-cms, destination dcache-se-atlas, destination cms-lvs-gridftp, destination srm-cms, destination srm-lhcb, destination cms-t2-se01, destination srm-eoslhcb, destination storm-fe-lhcb, destination se-iep-grid, destination grid-srm, destination cms-gridftp, destination atlassrm-kit, destination srm, destination atlas-gridftp, destination tech-se, destination ruhex-osgce, destination f-dpm001, destination lapp-se01, destination lapp-testse01, destination srmlhcb-tape, destination storm-fe, destination storm-se-01, destination cmseos-gridftp, destination red-gridftp, destination lcg-se0, destination lcg-se1, destination grid-se, destination dc2-grid-64, edu, gov, destination se, destination se01, destination gridftp, destination storm, destination se1, destination srm01, destination lcgsedc01, destination eoscmsftp, destination srmcms, destination cmsio, destination dcsrm, destination srmatlas, destination atlasse, destination srmv2, destination cmsdcatape01, destination gfe02, destination gftp, destination golias100, destination ccsrm, destination lpnse1, destination hephyse, destination storage01, destination se03, destination cmsdcadisk01, destination sdrm, destination transfer, destination se0002, destination tbit00, destination grid02, destination lcgdpmse, destination charon01, destination t2cmcondor, destination hepgrid11, destination heplnx204, destination marsedpm, destination head01, destination eosatlassftp, destination lhcbsdrm, destination node12, uni-wuppertal, t2, lcg, grid, gridka, peer, ncg, ...]
# 160  [xrdcl copyprocess run error server responded, error write permission denied, ca error error, de error error, nl error error, ru error error, destination atlasxrootd-kit, destination basilisk02, destination xrootd, destination sdrm, westgrid, gridka, grid, sara, t1, kiae]
# 6    [de error source srm get turl error, uk error source srm get turl error, es error source srm get turl error, jp error source srm get turl error, cz error source srm get turl error, gr error source srm get turl error, nl error source srm get turl error, org error source srm get turl error, sk error source srm get turl error, su error source srm get turl error, ru error source srm get turl error, fr error source srm get turl error, ua error source srm get turl error, cn error source srm get turl error, pl error source srm get turl error, ca error source srm get turl error, ch error source srm get turl error, fi error source srm get turl error, tr error source srm get turl error, il error source srm get turl error, tw error source srm get turl error, ee error source srm get turl error, au error source srm get turl error, kr error source srm get turl error, hu error source srm get turl error, cl error source srm get turl error, pt error source srm get turl error, ro error source srm get turl error, edu error source srm get turl error, gov error source srm get turl error, error source srm get turl error, destination lpsc-se-dpm-server, destination lcg-lrz-srm, destination cms-lvs-gridftp, destination storm-fe-cms, destination t2-srm-02, destination srm-cms, destination cms-t2-se01, destination srm-atlas, destination se-iep-grid, destination dcache-se-atlas, destination grid-srm, destination t2-dpm-01, destination storm-fe, destination srm, destination cms-se0, destination storm-se-01, destination se-goegrid, destination tech-se, destination recas-se-01, destination cmssrm-kit, destination fal-pygrid-30, destination uct2-dc1, destination atlassrm-kit, destination f-dpm001, destination atlassrm-fzk, destination cms-gridftp, destination lcg-se0, destination lapp-se01, destination lcg-se1, destination gridftp-vanderbilt, destination lcg-se01, destination tape-sdrm, destination atlas-gridftp, destination ingrid-se02, destination grid-cert-03, destination dc2-grid-64, destination dpm, destination se, destination se1, destination se01, destination atlas, destination gridftp, edu, destination sdrm, gov, destination cmsdcadisk01, destination gse1, destination dcsrm, destination osggridftp02, destination golias100, destination grid02, destination heplnx204, destination lcgdpmse, destination dp0015, destination t2cmcondor, destination lpnse1, destination srmifae, destination se03, destination ccsrm, destination eosatlassftp, destination sbgse1, destination marsedpm, destination srmv2, destination srmcms, destination grse001, destination lcgsedc01, destination madhatter, destination atlasse, destination se0002, ...]
# 20   [tr error destination checksum globus ftp client, edu error destination checksum globus ftp client, uk error transfer globus ftp client, tw error transfer globus ftp client, de error transfer globus ftp client, ch error transfer globus ftp client, edu error transfer globus ftp client, error service busy connection limit exceeded, ch error globus ftp client, de error globus ftp client, edu error globus ftp client, ru error globus ftp client, please try again later, destination dcache-se-atlas, closing control connection, destination lcg-se0, destination f-dpm001, destination ruhex-osgce, destination uct2-dc1, destination dc2-grid-64, edu, destination se01, destination bohr3226, destination torik1, destination osggridftp02, destination sdrm, destination eosatlassftp, server responded, grid, dur, scotgrid, ac, tier2, hep, manchester, ifh, sinica, ulakbim, gov, slac, stanford, rutgers, t1, kiae, cern, brunel, desy, uchicago]
# 211  [failed all protocols have been tried, xrdcl copyprocess run error server responded, destination dcache-atlas-xrootd-wan, destination xrootd-at1-door, org error error, es error error, de error error, destination xrootd, error authentication, aglt2, pic, desy]
# ..                                                                                                                                                                                                                                                                   ...
# 298  [inumber error deadlock detected detail process, ru error destination srm putdone error, destination tape-sdrm, t1, grid, kiae]
# 300  [de error destination srm putdone error, surl srm grid srm, >pnfsmanager@local timed out, destination grid-srm, de pnfs physik, rwth-aachen, rwth aachen, physik]
# 301  [server after attempts, destination dynafed02, heprc, uvic]
# 220  [gov error globus ftp client, error login incorrect, destination cmsdcatape01, server responded, fnal, user]
# 201  [uk error transfer globus ftp client, system call failed permission denied end, globus l file open failed, open file system error, open permission denied, error failed, destination gfe02, server responded, grid, hep, ph, ic, ac, unable]
#
# [329 rows x 6 columns]

# %% [markdown]
# Separating clusters containing fewer than 3 messages

# %%
clusters, outliers = cluster.split_clusters(cluster.result, 'cluster_size', threshold=3)

# %% [markdown]
# Top 10 clusters by the size of cluster

# %%
top_numb = 10
top_clusters = cluster.validation(clusters)[['cluster_size','pattern','mean_similarity']].sort_values(by=["cluster_size"], ascending=False) #clusters sorted by similarity inside the cluster
top_clusters.head(top_numb)
# Out:
#    cluster_size  \
# 0  55424
# 1  52867
# 2  42959
# 3  28596
# 4  27279
# 5  24969
# 6  24441
# 7  21696
# 8  20554
# 9  18381
#
#                                                                                                                                                                                                    pattern  \
# 0  DESTINATION  ERROR srm ifce err communication error on send err se  httpg srm cgsi gsoap running on reports error reading token data header connection
# 1  DESTINATION  ERROR error on xrdcl copyprocess run error server responded with an error write permission denied
# 2  DESTINATION  ERROR source srm get turl error on the turl request se  srm file unavailable file is .
# 3  DESTINATION  ERROR globus ftp client the server responded with an error service busy connection limit exceeded. please try again later. closing control connection.
# 4  DESTINATION  ERROR error on xrdcl copyprocess run error server responded with an error authentication to failed all protocols have been tried.
# 5  DESTINATION  ERROR protocol not supported or path url invalid root  atlasscratchdisk rucio tests
# 6  DESTINATION  ERROR error on xrdcl copyprocess run error server responded with an error unable to create permission denied
# 7  DESTINATION  ERROR transfer transfer canceled because the gsiftp performance marker timeout of seconds has been exceeded or all performance markers during that period indicated zero bytes transferred
# 8  DESTINATION  ERROR error reported from srm ifce se ls srm invalid path no such file or directory
# 9  DESTINATION  ERROR gfalt copy file perform copy error on xrdcl copyprocess run error server responded with an error
#
#    mean_similarity
# 0  0.77
# 1  0.89
# 2  0.87
# 3  0.88
# 4  0.92
# 5  0.80
# 6  0.92
# 7  0.91
# 8  0.89
# 9  0.97

# %% [markdown]
# Most inaccurate clusters

# %%
top_clusters[['cluster_size','pattern','mean_similarity']].sort_values(by=["mean_similarity"]).head(5)
# Out:
#     cluster_size  \
# 18  9370
# 61  1171
# 51  1605
# 57  1377
# 84  666
#
#                                                                                                pattern  \
# 18  DESTINATION  ERROR operation timed out
# 61  DESTINATION  ERROR srm ifce err connection timed out err se  etimedout httpg srm user timeout over
# 51  DESTINATION  ERROR srm operation canceled
# 57  DESTINATION  ERROR destination checksum operation timed out
# 84  DESTINATION  ERROR globus ftp client the operation was aborted
#
#     mean_similarity
# 18  0.65
# 61  0.67
# 51  0.68
# 57  0.70
# 84  0.71

# %%
print(cluster.in_cluster(cluster.result, 1)[[1,5,100]],"\n")
# Out:
# ['DESTINATION eosatlashttp.cern.ch ERROR transfer error copy failed with mode push with error request cancellation was requested.'
#  'DESTINATION webdav.grid.surfsara.nl ERROR transfer error copy failed with mode pull with error request cancellation was requested.'
#  'DESTINATION xfer.cr.cnaf.infn.it ERROR transfer error copy failed with mode pull with error request cancellation was requested.']
